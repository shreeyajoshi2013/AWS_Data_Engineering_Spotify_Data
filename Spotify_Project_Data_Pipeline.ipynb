# %%
#pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

client_id = "c0fdc1280ef44b71850d42ba200c12b3"
client_secret = "5100940dc8804cf585746154b90c3b22"
obj_client_credentials_manager = SpotifyClientCredentials(client_id,client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager = obj_client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1"

# %%
playlist_link.split('/')
# Out:
# ['https:',
#  '',
#  'open.spotify.com',
#  'playlist',
#  '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1']

# %%
playlist_link.split('/')[-1]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1'

# %%
playlist_link.split('/')[-1].split('?')
# Out:
# ['37i9dQZEVXbNG2KDcFcKOF', 'si=1333723a6eff4b7f&nd=1']

# %%
playlist_id = playlist_link.split('/')[-1].split('?')[0]
print(playlist_id)
# Out:
# 37i9dQZEVXbNG2KDcFcKOF

# %%
data = sp.playlist_tracks(playlist_id)

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbNG2KDcFcKOF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-05-31T16:25:46Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2024-05-31T16:25:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-05-31T16:25:46Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
len(data['items'])
# Out:
# 50

# %%
len(data['items'][1])
# Out:
# 6

# %%
data['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
data['items'][0]['track'].keys()
# Out:
# dict_keys(['preview_url', 'available_markets', 'explicit', 'type', 'episode', 'track', 'album', 'artists', 'disc_number', 'track_number', 'duration_ms', 'external_ids', 'external_urls', 'href', 'id', 'name', 'popularity', 'uri', 'is_local'])

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
data['items'][0]['track']['album'].keys()
# Out:
# dict_keys(['available_markets', 'type', 'album_type', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'uri', 'artists', 'external_urls', 'total_tracks'])

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7aJuG4TFXa2hmE4z1yxc3n'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'HIT ME HARD AND SOFT'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-05-17'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    ablum_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,
                     'album_name':album_name,
                     'ablum_release_date':ablum_release_date,
                     'album_total_tracks':album_total_tracks,
                     'album_url':album_url
                    }
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'ablum_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'album_name': 'Espresso',
#   'ablum_release_date': '2024-04-12',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '52TwRwdTUMtkpglbOE5IRz',
#   'album_name': 'MILLION DOLLAR BABY',
#   'ablum_release_date': '2024-04-26',
#   'album_total_tracks': 2,
#   'album_url': 'https://open.spotify.com/album/52TwRwdTUMtkpglbOE5IRz'},
#  {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album_name': 'Not Like Us',
#   'ablum_release_date': '2024-05-04',
#   'album_total_tracks': 1,
#   'album_url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
# ...

# %%
data['items'][8]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#   'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#   'id': '2FXC3k01G6Gw61bmprjgqS',
#   'name': 'Hozier',
#   'type': 'artist',
#   'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in (value['artists']):
                artist_dict = {'artist_id':artist['id'],
                               'artist_name': artist['name'],
                               'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '1WaFQSHVGZQJTbf0BdxdNo',
#   'artist_name': 'Tommy Richman',
#   'external_url': 'https://api.spotify.com/v1/artists/1WaFQSHVGZQJTbf0BdxdNo'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'external_url': 'https://api.spotify.com/v1/artists/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '7CvTknweLr9feJtRGrpDBy',
#   'artist_name': 'FloyyMenor',
#   'external_url': 'https://api.spotify.com/v1/artists/7CvTknweLr9feJtRGrpDBy'},
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '629DixmZGHc7ILtEntuiWE',
#   'song_name': 'LUNCH',
#   'duration_ms': 179586,
#   'url': 'https://open.spotify.com/track/629DixmZGHc7ILtEntuiWE',
#   'popularity': 96,
#   'song_added': '2024-05-31T16:25:46Z',
#   'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'song_id': '2qSkIjg1o9h3YT9RAgYN75',
#   'song_name': 'Espresso',
#   'duration_ms': 175459,
#   'url': 'https://open.spotify.com/track/2qSkIjg1o9h3YT9RAgYN75',
#   'popularity': 99,
#   'song_added': '2024-05-31T16:25:46Z',
#   'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'artist_id': '74KM79TiuVKeVCqs8QtB0B'},
#  {'song_id': '7fzHQizxTqy8wTXwlrgPQQ',
#   'song_name': 'MILLION DOLLAR BABY',
#   'duration_ms': 155151,
#   'url': 'https://open.spotify.com/track/7fzHQizxTqy8wTXwlrgPQQ',
#   'popularity': 99,
#   'song_added': '2024-05-31T16:25:46Z',
#   'album_id': '52TwRwdTUMtkpglbOE5IRz',
#   'artist_id': '1WaFQSHVGZQJTbf0BdxdNo'},
#  {'song_id': '6AI3ezQ4o3HUoP6Dhudph3',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)
artist_df = pd.DataFrame.from_dict(artist_list)
song_df = pd.DataFrame.from_dict(song_list)

# %%
album_df.head()
# Out:
#                  album_id            album_name ablum_release_date  \
# 0  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT         2024-05-17
# 1  5quMTd5zeI9yW5UDua8wS4              Espresso         2024-04-12
# 2  52TwRwdTUMtkpglbOE5IRz   MILLION DOLLAR BABY         2024-04-26
# 3  5JjnoGJyOxfSZUZtk2rRwZ           Not Like Us         2024-05-04
# 4  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT         2024-05-17
#
#    album_total_tracks                                          album_url
# 0                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 1                   1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 2                   2  https://open.spotify.com/album/52TwRwdTUMtkpgl...
# 3                   1  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...
# 4                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   album_id            50 non-null     object
#  1   album_name          50 non-null     object
#  2   ablum_release_date  50 non-null     object
#  3   album_total_tracks  50 non-null     int64
#  4   album_url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53 entries, 0 to 66
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     53 non-null     object
#  1   artist_name   53 non-null     object
#  2   external_url  53 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
song_df.head()
# Out:
#                   song_id            song_name  duration_ms  \
# 0  629DixmZGHc7ILtEntuiWE                LUNCH       179586
# 1  2qSkIjg1o9h3YT9RAgYN75             Espresso       175459
# 2  7fzHQizxTqy8wTXwlrgPQQ  MILLION DOLLAR BABY       155151
# 3  6AI3ezQ4o3HUoP6Dhudph3          Not Like Us       274192
# 4  6dOtVTDdiauQNBQEDOtlAB   BIRDS OF A FEATHER       210373
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/629DixmZGHc7ILt...          96
# 1  https://open.spotify.com/track/2qSkIjg1o9h3YT9...          99
# 2  https://open.spotify.com/track/7fzHQizxTqy8wTX...          99
# 3  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...          98
# 4  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          95
#
#              song_added                album_id               artist_id
# 0  2024-05-31T16:25:46Z  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH
# ...

# %%
album_df['release_date'] = pd.to_datetime(album_df['ablum_release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
import sys 
print(sys. version)
# Out:
# 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]
